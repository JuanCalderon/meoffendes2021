# %%
from microtc.utils import load_model

results = load_model('total_results.df')
results

# f1_score y recall son usando el X_train sin modificaciones ni cluster
# cluster_f1_score y cluster_recall son modificando el X_train con el cluster
# Out:
#                        ds_name                                        tok_lst  \
# 0   meoffendes2021_mx_Es_train                                           [-1]
# 1   meoffendes2021_mx_Es_train                                           [-3]
# 2   meoffendes2021_mx_Es_train                                            [3]
# 3   meoffendes2021_mx_Es_train                                            [5]
# 4   meoffendes2021_mx_Es_train  [-1, [2, 1], [3, 1], [2, 2], [3, 2], 2, 3, 4]
# 5   meoffendes2021_mx_Es_train                                [-1, [2, 1], 3]
# 6            haha2018_Es_train                                           [-1]
# 7            haha2018_Es_train                                           [-3]
# 8            haha2018_Es_train                                            [3]
# 9            haha2018_Es_train                                            [5]
# 10           haha2018_Es_train  [-1, [2, 1], [3, 1], [2, 2], [3, 2], 2, 3, 4]
# ...
